# %%
from google.colab import files  
import pandas as pd 

from google.colab import drive
drive.mount('/content/drive') #connect the colab notebook to google drive
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/Grad School/Ukraine War Project/Data/Twitter_Data/all_tweets_test_2.csv")
# Out:
# /usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data["Search_Key-Words"].value_counts()
# Out:
# russia+war             35040
# ukraine                34357
# putin+war              34117
# russia                 28987
# green+energy           28496
# ukraine+oil            23736
# russia+invasion        21068
# zelenskyy              19110
# NATO                   17999
# natural+gas            16442
# ukraine+energy         15303
# putin+oil              14941
# putin                  14774
# putin+energy            7064
# war+energy              6737
# zelenskyy+war           5859
# stock+energy            2902
# ukraine+stock           2530
# russia+stock            2062
# war+stock               1958
# ukriane                 1483
# putin+stock              493
# kyiv+oil                 371
# russia+natural+gas       172
# kyiv+energy              164
# ukraine+natural+gas       44
# kyiv+stock                39
# zelenskyy+oil             27
# zelenskyy+energy          21
# zelenskyy+stock            5
# Name: Search_Key-Words, dtype: int64

# %%
top_key_words = ["russia+war",
"ukraine",
"putin+war",
"russia",
"green+energy",
"ukraine+oil",
"russia+invasion",
"zelenskyy",
"NATO",
"natural+gas",
"ukraine+energy",
"putin+oil",
"putin"]

top_data = data[data['Search_Key-Words'].isin(top_key_words)]

# %%
top_data['Search_Key-Words'].value_counts()
# Out:
# russia+war         35040
# ukraine            34357
# putin+war          34117
# russia             28987
# green+energy       28496
# ukraine+oil        23736
# russia+invasion    21068
# zelenskyy          19110
# NATO               17999
# natural+gas        16442
# ukraine+energy     15303
# putin+oil          14941
# putin              14774
# Name: Search_Key-Words, dtype: int64

# %%
data_sample = top_data.sample(30000,random_state=42)

data_sample['Search_Key-Words'].value_counts()
# Out:
# russia+war         3534
# putin+war          3424
# ukraine            3261
# russia             2843
# green+energy       2831
# ukraine+oil        2412
# russia+invasion    2050
# zelenskyy          1885
# NATO               1726
# natural+gas        1603
# ukraine+energy     1530
# putin              1477
# putin+oil          1424
# Name: Search_Key-Words, dtype: int64

# %%
#data_sample.to_csv("/content/drive/MyDrive/Grad School/Ukraine War Project/Data/Twitter_Data/small_sample_data.csv")

data = pd.read_csv("/content/drive/MyDrive/Grad School/Ukraine War Project/Data/Twitter_Data/small_sample_data.csv")

# %%
Members=[
"Dylan",
"Darshan",
"Kruttika",
"Krutik",
"Priti",
"Ty",
"Vedant",
"Ashmita",
"Logan",
"Prathamesh",
"Belal"
]

for i,member in enumerate(Members):
  cur = data.iloc[1000*i:1000*(i+1)]
  cur.to_csv("/content/drive/MyDrive/Grad School/Ukraine War Project/Data/Twitter_Data/"+member+"_sample_data.csv")

# %%
+len(data)
# Out:
# 30000

# %%
data.iloc[6000:7000]
# Out:
#       Unnamed: 0  Unnamed: 0.1             tweet_id  \
# 6000       95430         10227  1519808600675217408
# 6001      225575           529  1519743532617019392
# 6002      319841          3597  1519718903806668801
# 6003      277227         10988  1519804590845304832
# 6004      246216          7528  1518756365061173248
# ...          ...           ...                  ...
# 6995      328745         14630  1518161506747273218
# 6996      124883          5362  1520151417507487750
# 6997      272075          5595  1519815581943631872
# 6998      238737          4113  1520642534694813696
# 6999       21133          3137  1519638044877463554
#
#                                                    text  \
# 6000  The city on the edge of Europe where tens of t...
# 6001  @AUC_MoussaFaki @_AfricanUnion Black students ...
# 6002  @FletchFFletch4 @graupepillard @jerrysaltz OK ...
# 6003  This probably should be filed in the category ...
# ...

# %%
col1=input("Please choose a color among red, blue, and yellow: ")

col2=input("Please choose two colors among red, blue, and yellow to mix with first color you chose: ")

if (col1 == red or blue or yellow)  and (col2 == red or blue or yellow) and (col1!=col2)  

  if col1==red and  col2==blue or col1==blue and col2==red :

   print("When you mix red and blue, you get purple")

  elif col1==red and  col2==yellow or col1==yellow and col2==red :

   print("When you mix red and yellow, you get orange.")

  else col1==blue and  col2==yellow or col1==yellow and col2==blue :

   print("When you mix blue and yellow, you get green.")

else : 

 print("invalid input, choose again.")
# Out:
# Enter favorite color:yellow
# Enter pet's name:daisy
# Enter a number:5
# You entered: yellow daisy 5
# First password: yellow_daisy
# Second password: 5yellow5
# Number of characters in yellow_daisy : 12
# Number of characters in yellow_daisy : 8

# %% [markdown]
# Given an integer representing a 10-digit phone number, output the area code, prefix, and line number using the format (800) 555-1212.
#
# Ex: If the input is:
#
# 8005551212
# the output is:
#
# (800) 555-1212
# Hint: Use % to get the desired rightmost digits. Ex: The rightmost 2 digits of 572 is gotten by 572 % 100, which is 72.
#
# Hint: Use // to shift right by the desired amount. Ex: Shifting 572 right by 2 digits is done by 572 // 100, which yields 5. (Recall integer division discards the fraction).
#
# For simplicity, assume any part starts with a non-zero digit. So 0119998888 is not allowed.

# %%
# Input
# 8005551212

#Output (800) - 555 -1212



#phone_number = 8005551212
phone_number = int(input("Enter Phone number: "))

print


print(phone_number / 10000000)
first3 = phone_number // 10000000

phone_number2 = phone_number % 10000000
print(first3)
print(phone_number2)

second3 = phone_number2 // 10000



thrid3 = 0



print(second3)
# Out:
# Enter Phone number: 3234569898
# 323.4569898
# 323
# 4569898
# 323456

# %%
9/4
# Out:
# 2.25
